# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
    import pandas as pd
    try:
        df = pd.read_csv('airbnb_listings.csv', encoding='latin1')
    except UnicodeDecodeError:
        try:
            df = pd.read_csv('airbnb_listings.csv', encoding='cp1252')
        except UnicodeDecodeError:
            df = pd.read_csv('airbnb_listings.csv', encoding='iso-8859-1')

# %% [markdown]
# Observations on shape of data

# %%
df.head()
# Out:
#     host_id host_name      city state     zipcode        country   latitude  \
# 0   5867023   Michael  New York    NY  10022-4175  United States  40.756852
# 1   2631556    Denise  New York    NY         NaN  United States  40.830599
# 2   4601412      Miao  Brooklyn    NY       11221  United States  40.692189
# 3    198425      Sara  New York    NY       10011  United States  40.734751
# 4  22590025   Charles  New York    NY       10011  United States  40.745282
#
#    longitude property_type        room_type  ...  beds  bed_type  square_feet  \
# 0 -73.964754     Apartment  Entire home/apt  ...   1.0  Real Bed          NaN
# 1 -73.941014     Apartment  Entire home/apt  ...   3.0  Real Bed          NaN
# 2 -73.924120     Apartment     Private room  ...   2.0  Real Bed          NaN
# 3 -74.002592     Apartment  Entire home/apt  ...   1.0  Real Bed          NaN
# 4 -73.997836     Apartment  Entire home/apt  ...   2.0  Real Bed          NaN
#
# ...

# %%
df.tail()
# Out:
#        host_id      host_name            city state zipcode        country  \
# 27387  1485898             Js        New York    NY   10016  United States
# 27388  5944682  Maja & Pierre        New York    NY   10019  United States
# 27389  2675644         Alissa  Staten Island     NY   10301  United States
# 27390   322716           Alex        Brooklyn    NY   11213  United States
# 27391  2695451           Elle        New York    NY   10018  United States
#
#         latitude  longitude property_type        room_type  ...  beds  \
# 27387  40.742363 -73.981968     Apartment  Entire home/apt  ...   1.0
# 27388  40.759642 -73.985343     Apartment     Private room  ...   1.0
# 27389  40.645741 -74.080955         House  Entire home/apt  ...   3.0
# 27390  40.669931 -73.946820     Apartment  Entire home/apt  ...   1.0
# 27391  40.753941 -73.993232     Apartment      Shared room  ...   1.0
#
#        bed_type  square_feet     price availability_365  number_of_reviews  \
# ...

# %%
df.shape
# Out:
# (27392, 23)

# %%
df.dtypes
# Out:
# host_id                        int64
# host_name                     object
# city                          object
# state                         object
# zipcode                       object
# country                       object
# latitude                     float64
# longitude                    float64
# property_type                 object
# room_type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                         float64
# bed_type                      object
# square_feet                  float64
# price                         object
# availability_365               int64
# number_of_reviews              int64
# review_scores_rating         float64
# review_scores_cleanliness    float64
# review_scores_location       float64
# review_scores_value          float64
# dtype: object

# %% [markdown]
# Detecting Missing Values

# %%
df.isna().sum()
# Out:
# host_id                          0
# host_name                        0
# city                             0
# state                            2
# zipcode                        162
# country                          1
# latitude                         0
# longitude                        0
# property_type                    6
# room_type                        0
# accommodates                     0
# bathrooms                      463
# bedrooms                       140
# beds                            98
# bed_type                         0
# square_feet                  26386
# price                            0
# availability_365                 0
# number_of_reviews                0
# review_scores_rating          8657
# review_scores_cleanliness     8731
# review_scores_location        8732
# review_scores_value           8734
# dtype: int64

# %% [markdown]
# Feature engineering - 1

# %%
df.drop('host_id', axis=1, inplace=True)

# %%
df.drop('square_feet', axis=1, inplace=True)

# %%
df.drop('country', axis=1, inplace=True)

# %% [markdown]
# Statistical Summary

# %%
df.describe(include='all')
# Out:
#        host_name      city  state zipcode      latitude     longitude  \
# count      27392     27392  27390   27230  27392.000000  27392.000000
# unique      7381       185      4     185           NaN           NaN
# top        David  New York     NY   11211           NaN           NaN
# freq         247     15656  27386    1200           NaN           NaN
# mean         NaN       NaN    NaN     NaN     40.733070    -73.964276
# std          NaN       NaN    NaN     NaN      0.048968      0.035162
# min          NaN       NaN    NaN     NaN     40.509611    -74.239539
# 25%          NaN       NaN    NaN     NaN     40.699655    -73.988449
# 50%          NaN       NaN    NaN     NaN     40.728024    -73.966075
# 75%          NaN       NaN    NaN     NaN     40.764030    -73.947260
# max          NaN       NaN    NaN     NaN     40.907704    -73.726710
#
#        property_type        room_type  accommodates     bathrooms  \
# ...

# %% [markdown]
# Univariate and Bivariate Analysis

# %%
for col in df.columns:
    if df[col].dtype != 'object':
        plt.figure(figsize=(8, 4))
        plt.title(f'Distribution of {col}')
        sns.histplot(df[col].dropna(), kde=True)
        plt.show()

        plt.figure(figsize=(8, 4))
        plt.title(f'Boxplot of {col}')
        sns.boxplot(y=col, data=df)

# %% [markdown]
# Duplicate value check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Missing value treatment

# %%
x = df.drop('price', axis=1)

# %%
y = df['price']

# %%
x.shape, y.shape
# Out:
# ((27392, 19), (27392,))

# %%
x.isna().sum()
# Out:
# host_name                       0
# city                            0
# state                           2
# zipcode                       162
# latitude                        0
# longitude                       0
# property_type                   6
# room_type                       0
# accommodates                    0
# bathrooms                     463
# bedrooms                      140
# beds                           98
# bed_type                        0
# availability_365                0
# number_of_reviews               0
# review_scores_rating         8657
# review_scores_cleanliness    8731
# review_scores_location       8732
# review_scores_value          8734
# dtype: int64

# %%
x.drop('state', axis=1, inplace=True)

# %%
x.drop('zipcode', axis=1, inplace=True)

# %%
x ['property_type'].fillna('unknown', inplace=True)

# %%
x['bathrooms'].fillna(x['bathrooms'].median(), inplace=True)

# %%
x['bedrooms'].fillna(x['bedrooms'].median(), inplace=True)

# %%
x['beds'].fillna(x['beds'].median(), inplace=True)

# %%
x['review_scores_rating'].fillna(x['review_scores_rating'].median(), inplace=True)

# %%
x['review_scores_cleanliness'].fillna(x['review_scores_cleanliness'].median(), inplace=True)

# %%
x['review_scores_location'].fillna(x['review_scores_location'].median(), inplace=True)

# %%
x['review_scores_value'].fillna(x['review_scores_value'].median(), inplace=True)

# %%
x.isna().sum()
# Out:
# host_name                    0
# city                         0
# latitude                     0
# longitude                    0
# property_type                0
# room_type                    0
# accommodates                 0
# bathrooms                    0
# bedrooms                     0
# beds                         0
# bed_type                     0
# availability_365             0
# number_of_reviews            0
# review_scores_rating         0
# review_scores_cleanliness    0
# review_scores_location       0
# review_scores_value          0
# dtype: int64

# %% [markdown]
# Outlier Treatment

# %%
numerical_cols = []
for c in df.columns:
    if df[c].dtype != 'object':
        numerical_cols.append(c)

# %%
for c in numerical_cols:
    Q1 = x[c].quantile(0.25)
    Q3 = x[c].quantile(0.75)
    IQR = Q3-Q1
    upper_whisker = Q3 + (1.5*IQR)
    lower_whisker = Q1 - (1.5*IQR)
    median = x[c].median()
    idx = x[(x[c] > upper_whisker) | (x[c] < lower_whisker)].index
    x[c].iloc[idx] = median

    sns.boxplot(y=x[c], data=x)
    plt.show()

# %% [markdown]
# Feature engineering - 2

# %%
y.dtype
# Out:
# dtype('O')

# %%
x.dtypes
# Out:
# host_name                     object
# city                          object
# latitude                     float64
# longitude                    float64
# property_type                 object
# room_type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                         float64
# bed_type                      object
# availability_365               int64
# number_of_reviews              int64
# review_scores_rating         float64
# review_scores_cleanliness    float64
# review_scores_location       float64
# review_scores_value          float64
# dtype: object

# %%
x.drop('host_name', axis=1, inplace=True)

# %%
x.drop('city', axis=1, inplace=True)

# %% [markdown]
# Encoding categorical columns

# %%
x['property_type'].value_counts()
# Out:
# property_type
# Apartment          24909
# House               1575
# Loft                 601
# Bed & Breakfast      170
# Dorm                  49
# Other                 48
# Boat                  11
# unknown                6
# Treehouse              6
# Villa                  4
# Tent                   3
# Cabin                  3
# Hut                    1
# Castle                 1
# Chalet                 1
# Cave                   1
# Earth House            1
# Lighthouse             1
# Camper/RV              1
# Name: count, dtype: int64

# %%
from category_encoders import TargetEncoder
encoder = TargetEncoder()

# %%
x ['property_type'] = encoder.fit_transform(x['property_type'], y)

# %%
x['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    15977
# Private room       10586
# Shared room          829
# Name: count, dtype: int64

# %%
x['room_type'] = encoder.fit_transform(x['room_type'], y)

# %%
x ['bed_type'] = encoder.fit_transform(x['bed_type'], y)

# %%
x.dtypes
# Out:
# latitude                     float64
# longitude                    float64
# property_type                float64
# room_type                    float64
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                         float64
# bed_type                     float64
# availability_365               int64
# number_of_reviews              int64
# review_scores_rating         float64
# review_scores_cleanliness    float64
# review_scores_location       float64
# review_scores_value          float64
# dtype: object

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(x)
# Out:
# array([[ 0.52319312,  0.08042551, -0.28388025, ..., -0.28628058,
#          0.60049498, -0.27302869],
#        [ 2.12486549,  0.98452713, -0.28388025, ..., -1.94206556,
#          0.60049498, -2.02861595],
#        [-0.8811779 ,  1.62792131, -0.28388025, ...,  1.3695044 ,
#         -0.91454219,  1.48255858],
#        ...,
#        [-1.88996845,  0.03014037,  3.86526983, ..., -0.28628058,
#         -0.91454219, -2.02861595],
#        [-1.3645873 ,  0.76343726, -0.28388025, ...,  1.3695044 ,
#         -0.91454219,  1.48255858],
#        [ 0.45997813, -1.00410493, -0.28388025, ..., -0.28628058,
#          0.60049498,  1.48255858]], shape=(27392, 15))

# %%
y = y.str.replace('$', '').str.replace(',', '').astype(float)

# %% [markdown]
# Dividing into train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Application of Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# Accumulating Predictions

# %%
y_hat_train = model.predict(xtrain)

# %%
y_hat_train
# Out:
# array([118.80432188,  90.65764234,  38.34858703, ..., 262.75740544,
#        256.05655139,  55.91646753], shape=(21913,))

# %%
model.coef_
# Out:
# array([ 3.25830902e+02, -1.43427635e+03,  7.66964901e-01, -7.45496745e-01,
#         1.57639504e+01, -2.25952590e-12,  2.16004992e-12,  1.80649091e+01,
#        -1.71028818e-01,  1.84409536e-01, -2.39465023e+00,  1.48745281e+00,
#        -9.05065655e-01,  2.30987292e+01, -1.09158784e+01])

# %%
y_hat_test = model.predict(xtest)

# %%
y_hat_test
# Out:
# array([256.76015756, 200.46154232, 198.75808774, ...,  79.78653505,
#         31.20499994, 118.97794173], shape=(5479,))

# %%
from sklearn.metrics import root_mean_squared_error, mean_squared_error

# %%
train_mse = mean_squared_error(ytrain, y_hat_train)
train_mse
# Out:
# 45240.75595242618

# %%
test_mse = mean_squared_error(ytest, y_hat_test)
test_mse
# Out:
# 35362.9223802657

# %%
rmse_train = root_mean_squared_error(ytrain, y_hat_train)
rmse_train
# Out:
# 212.69874459532238

# %%
rmse_test = root_mean_squared_error(ytest, y_hat_test)
rmse_test
# Out:
# 188.05031874545094

# %%
from sklearn.metrics import r2_score

# %%
train_r2 = model.score(xtrain, ytrain)
train_r2
# Out:
# 0.13841287112368716

# %%
test_r2 = model.score(xtest, ytest)
test_r2
# Out:
# 0.16571328107389705

# %%
def adjusted_r2(r2, m, d):
    return (1 - (((1-r2)*(m-1))/(m-d-1)))

# %%
m1 = xtrain.shape[0]
d1 = xtrain.shape[1]

m1,d1
# Out:
# (21913, 15)

# %%
train_adj = adjusted_r2(train_r2, m1, d1)
train_adj
# Out:
# 0.13782266210267313

# %%
m2 = xtest.shape[0]
d2 = xtest.shape[1]

m2,d2
# Out:
# (5479, 15)

# %%
test_adj = adjusted_r2(test_r2, m2, d2)
test_adj
# Out:
# 0.163422543240492

# %% [markdown]
# Applying L1 and L2 Regularization

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
alpha_array = [0.001, 1e1, 1e10]

# %%
lasso_test_score = {}
ridge_test_score = {}

# %%
for i in range(len(alpha_array)):
    
    lasso_model = Lasso(alpha = alpha_array[i])
    ridge_model = Ridge(alpha = alpha_array[i])
    
    lasso_model.fit(xtrain, ytrain)
    ridge_model.fit(xtrain, ytrain)

    lasso_test_predictions = lasso_model.predict(xtest)
    ridge_test_predictions = ridge_model.predict(xtest)

    lasso_score = lasso_model.score(xtest, ytest)
    ridge_score = ridge_model.score(xtest, ytest)

    lasso_test_score[alpha_array[i]] = round(lasso_score,2)
    ridge_test_score[alpha_array[i]] = round(ridge_score,2)

# %% [markdown]
# L1 and L2 Scores

# %%
lasso_test_score
# Out:
# {0.001: 0.17, 10.0: 0.13, 10000000000.0: -0.0}

# %%
ridge_test_score
# Out:
# {0.001: 0.17, 10.0: 0.16, 10000000000.0: 0.0}

# %% [markdown]
# KNN Regression

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
knn.fit(xtrain, ytrain)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
score = round(knn.score(xtrain, ytrain)*100,2)
score
# Out:
# 27.04

# %%
y_pred = knn.predict(xtrain)

# %%
print("Actual values:", ytest)
# Out:
# Actual values: 23048    199.0
# 18838    230.0
# 23685    134.0
# 2388     130.0
# 22991     80.0
#          ...
# 24836    110.0
# 10852     60.0
# 19119     90.0
# 23412     89.0
# 15170     88.0
# Name: price, Length: 5479, dtype: float64

# %%
print("Predicted values:", y_pred)
# Out:
# Predicted values: [ 80.  39.  60. ...  65. 150.  39.]

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor()

# %%
print(f"Training Score: {model.score(xtrain, ytrain)}")
# Out:
# Training Score: 0.9999882794937147

# %%
print(f"Test Score: {model.score(xtest, ytest)}")
# Out:
# Test Score: -0.6562507635441266
